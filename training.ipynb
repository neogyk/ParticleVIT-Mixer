# %% [markdown]
# <a href="https://colab.research.google.com/github/neogyk/ParticleVIT-Mixer/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# !git clone https://github.com/neogyk/ParticleVIT-Mixer

# %%
# !git clone https://github.com/neogyk/ParticleVIT-Mixer
# Out:
# Cloning into 'ParticleVIT-Mixer'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 142 (delta 78), reused 130 (delta 70), pack-reused 0 (from 0)
# Receiving objects: 100% (142/142), 5.78 MiB | 18.96 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
import os
os.chdir('ParticleVIT-Mixer')

# %%
# !uv pip install torch --no-build-isolation
# Out:
# ...
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 82ms

# %%
# !uv pip install -r pyproject.toml
# Out:
# ...
# Using Python 3.12.12 environment at: /usr
# Resolved 109 packages in 106ms
# Prepared 2 packages in 8m 08s
# Uninstalled 2 packages in 188ms
# Installed 30 packages in 212ms
#  + adabelief-pytorch==0.2.1
#  + adam-atan2-pytorch==0.2.4
#  + awkward==2.9.0
#  + awkward-cpp==52
#  + colorama==0.4.6
#  + coverage==7.13.4
#  + einx==0.3.0
#  + fastparquet==2025.12.0
#  + hdf5plugin==6.0.0
#  + lightning==2.6.1
#  + lightning-utilities==0.15.3
#  + lion-pytorch==0.2.3
#  + loguru==0.7.3
#  + mixture-of-experts==0.2.3
#  - pandas==2.2.2
#  + pandas==2.3.3
#  + pytorch-lightning==2.6.1
#  + soft-moe==0.0.1
#  + torch-cluster==1.6.3
#  + torch-ema==0.3
#  + torch-geometric==2.7.0
#  + torch-scatter==2.1.2
#  + torch-sparse==0.6.18
#  + torch-vision==0.1.6.dev0
#  + torchmetrics==1.8.2
#  + uproot==5.7.1
#  + vector==1.8.0
#  - wandb==0.25.0
#  + wandb==0.23.1
#  + wget==3.2
#  + x-transformers==2.16.1
#  + zenodo-get==2.0.0

# %%
import sys
# !pip uninstall torchmetrics
# !pip uninstall torchvision
# Out:
# Found existing installation: torchmetrics 1.8.2
# Uninstalling torchmetrics-1.8.2:
#   Would remove:
#     /usr/local/lib/python3.12/dist-packages/torchmetrics-1.8.2.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/torchmetrics/*
# Proceed (Y/n)? y
#   Successfully uninstalled torchmetrics-1.8.2
# Found existing installation: torchvision 0.25.0+cpu
# Uninstalling torchvision-0.25.0+cpu:
#   Would remove:
#     /usr/local/lib/python3.12/dist-packages/torchvision-0.25.0+cpu.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libjpeg.4af9affd.so.8
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libpng16.c2edc9e1.so.16
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libsharpyuv.994c9d2c.so.0
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libwebp.87a45f40.so.7
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libz.03209371.so.1
#     /usr/local/lib/python3.12/dist-packages/torchvision/*
# ...

# %%
from __future__ import annotations
import argparse, sys
import pdb
import importlib
import torch
#import torchmetrics
from graph_mixer import GraphMLPMixer
from graph_mixer.data_processing import *
from graph_mixer.loss import FocalLoss
from utils import seed_worker, set_seed, weight_init
from adam_atan2_pytorch import AdamAtan2
from adabelief_pytorch import AdaBelief
from lion_pytorch import Lion
import pytorch_lightning as pl
from lightning.pytorch.loggers import WandbLogger
from torch_geometric.loader.dataloader import DataLoader
from matplotlib import pyplot as plt
from dataclasses import asdict
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-601/1876406334.py in <cell line: 0>()
#       5 import torch
#       6 #import torchmetrics
# ----> 7 from graph_mixer import GraphMLPMixer
#       8 from graph_mixer.data_processing import *
#       9 from graph_mixer.loss import FocalLoss
#
# /content/ParticleVIT-Mixer/graph_mixer/__init__.py in <module>
#       9 from torch_scatter import scatter
#      10 from pe import *
# ---> 11 from soft_moe import SoftMoELayerWrapper
#      12 from graph_mixer.mamba import MambaSSM
#      13 from graph_mixer.hrm import HRM
#
# /usr/local/lib/python3.12/dist-packages/soft_moe/__init__.py in <module>
#       1 from soft_moe.soft_moe import SoftMoELayerWrapper
# ----> 2 from soft_moe.vision_transformer import (SoftMoEVisionTransformer,
# ...
